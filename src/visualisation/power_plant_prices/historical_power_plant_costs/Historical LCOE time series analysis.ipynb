# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
long_lcoe = pd.read_csv('/Users/b1017579/Documents/PhD/Projects/10. ELECSIM/data/processed/power_plants/power_plant_costs/historical_power_plant_costs/historical_power_plant_costs_long.csv')
long_lcoe
# Out:
#      Unnamed: 0        Technology  Discount_rate  Year        lcoe
# 0             0              CCGT          0.050  1981         NaN
# 1             1              Coal          0.050  1981  177.192960
# 2             2           Nuclear          0.050  1981  123.832320
# 3             3           Onshore          0.075  1981         NaN
# 4             4      PV - Utility          0.075  1981         NaN
# 5             5  Hydropower <10MW          0.075  1981         NaN
# 6             6  Hydropower >10MW          0.075  1981         NaN
# 7             7         Bioenergy          0.075  1981         NaN
# 8             8          Offshore          0.089  1981         NaN
# 9             9              CCGT          0.050  1984         NaN
# 10           10              Coal          0.050  1984  102.932480
# 11           11           Nuclear          0.050  1984   66.990080
# 12           12           Onshore          0.075  1984         NaN
# 13           13      PV - Utility          0.075  1984         NaN
# 14           14  Hydropower <10MW          0.075  1984         NaN
# 15           15  Hydropower >10MW          0.075  1984         NaN
# 16           16         Bioenergy          0.075  1984         NaN
# 17           17          Offshore          0.089  1984         NaN
# 18           18              CCGT          0.050  1989         NaN
# 19           19              Coal          0.050  1989   80.015360
# 20           20           Nuclear          0.050  1989   75.243520
# 21           21           Onshore          0.075  1989  227.845116
# 22           22      PV - Utility          0.075  1989         NaN
# 23           23  Hydropower <10MW          0.075  1989         NaN
# 24           24  Hydropower >10MW          0.075  1989         NaN
# 25           25         Bioenergy          0.075  1989         NaN
# 26           26          Offshore          0.089  1989         NaN
# 27           27              CCGT          0.050  1990         NaN
# 28           28              Coal          0.050  1990         NaN
# 29           29           Nuclear          0.050  1990         NaN
# ..          ...               ...            ...   ...         ...
# 249         249  Hydropower >10MW          0.075  2014  135.229240
# 250         250         Bioenergy          0.075  2014   87.533311
# 251         251          Offshore          0.089  2014  131.704996
# 252         252              CCGT          0.050  2015  103.690240
# 253         253              Coal          0.050  2015         NaN
# 254         254           Nuclear          0.050  2015   82.821120
# 255         255           Onshore          0.075  2015   75.543607
# 256         256      PV - Utility          0.075  2015  159.505145
# 257         257  Hydropower <10MW          0.075  2015  103.826024
# 258         258  Hydropower >10MW          0.075  2015  135.229240
# 259         259         Bioenergy          0.075  2015   87.533311
# 260         260          Offshore          0.089  2015         NaN
# 261         261              CCGT          0.050  2016         NaN
# 262         262              Coal          0.050  2016         NaN
# 263         263           Nuclear          0.050  2016         NaN
# 264         264           Onshore          0.075  2016   76.716725
# 265         265      PV - Utility          0.075  2016  158.338034
# 266         266  Hydropower <10MW          0.075  2016  103.826024
# 267         267  Hydropower >10MW          0.075  2016  135.229240
# 268         268         Bioenergy          0.075  2016   87.533311
# 269         269          Offshore          0.089  2016  115.486777
# 270         270              CCGT          0.050  2017         NaN
# 271         271              Coal          0.050  2017         NaN
# 272         272           Nuclear          0.050  2017         NaN
# 273         273           Onshore          0.075  2017         NaN
# 274         274      PV - Utility          0.075  2017  145.791593
# 275         275  Hydropower <10MW          0.075  2017  103.826024
# 276         276  Hydropower >10MW          0.075  2017  135.229240
# 277         277         Bioenergy          0.075  2017         NaN
# 278         278          Offshore          0.089  2017         NaN
#
# [279 rows x 5 columns]

# %%
tech_groups = long_lcoe.drop(['Discount_rate', 'Unnamed: 0'], axis=1).groupby('Technology')
rowlength = math.ceil(tech_groups.ngroups/2)

# %%
fig, axs = plt.subplots(nrows=rowlength, ncols=2, figsize=(30,30))

targets = zip(tech_groups.groups.keys(), axs.flatten())

for (key, ax) in targets:
    tech = tech_groups.get_group(key).sort_values("Year")
    tech = tech.dropna()
    ax.plot(tech['Year'], tech['lcoe'], marker='o')
    ax.set_title(key)
plt.show()

# %%
tech_groups.get_group("Coal")
# Out:
#     Technology  Year       lcoe
# 1         Coal  1981  177.19296
# 10        Coal  1984  102.93248
# 19        Coal  1989   80.01536
# 28        Coal  1990        NaN
# 37        Coal  1991        NaN
# 46        Coal  1992   89.86624
# 55        Coal  1993        NaN
# 64        Coal  1994        NaN
# 73        Coal  1995        NaN
# 82        Coal  1996        NaN
# 91        Coal  1997        NaN
# 100       Coal  1998        NaN
# 109       Coal  1999        NaN
# 118       Coal  2000        NaN
# 127       Coal  2001        NaN
# 136       Coal  2002        NaN
# 145       Coal  2003        NaN
# 154       Coal  2004        NaN
# 163       Coal  2005        NaN
# 172       Coal  2006        NaN
# 181       Coal  2007        NaN
# 190       Coal  2008        NaN
# 199       Coal  2009        NaN
# 208       Coal  2010        NaN
# 217       Coal  2011        NaN
# 226       Coal  2012        NaN
# 235       Coal  2013        NaN
# 244       Coal  2014        NaN
# 253       Coal  2015        NaN
# 262       Coal  2016        NaN
# 271       Coal  2017        NaN
