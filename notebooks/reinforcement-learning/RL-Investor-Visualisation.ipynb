# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# run = pd.read_csv('~/Documents/PhD/Projects/10. ELECSIM/run/reinforcement_learning/test_new/demand_none-carbon_none-datetime_2019-07-20_07-28-33-capacity_52152.csv')
# run = pd.read_csv('~/Documents/PhD/Projects/10. ELECSIM/test/test_new/demand_none-carbon_none-datetime_2019-07-21_10-43-02-capacity_52152.csv')
# run = pd.read_csv('~/Documents/PhD/Projects/10. ELECSIM/run/reinforcement_learning/test_new/demand_none-carbon_none-datetime_2019-07-20_08-32-53-capacity_52152.csv')
# run = pd.read_csv('~/Documents/PhD/Projects/10. ELECSIM/run/best_run_beis_comparison/demand_none-carbon_none-datetime_2019-08-26_18-27-45-capacity_52152.csv')
run = pd.read_csv('~/Desktop/demand_none-carbon_none-datetime_2019-11-11_15-30-46-capacity_3014.937499999999.csv')
run
# Out:
#      Unnamed: 0  contributed_CCGT  contributed_Coal  contributed_Onshore  \
# 0             0           29289.6          152107.2          1432.590051
# 1             1           29289.6          152107.2          1442.685414
# 2             2           29289.6          152107.2          1328.147978
# 3             3           29289.6          152107.2          1431.215813
# 4             4           23187.6          147414.6          1442.685414
# 5             5           29289.6          152107.2          1442.685414
# 6             6           21967.2          152107.2          1821.023651
# 7             7           25257.6          152107.2          2156.337674
# 8             8           29289.6          266673.6          1418.392976
# 9             9           27698.4          266673.6          1428.388293
# 10           10           26478.0          266673.6          1314.985932
# 11           11           28918.8          266673.6          1417.032357
# ...

# %%
# run_8 = run[run['Unnamed: 0']%8==0]
# run_8['Unnamed: 0'] = run_8['Unnamed: 0']/8
# run_8.head()
run_8 = run

# %%
total = run_8.filter(regex='total_|Unnamed').drop(columns='total_genco_wealth')
total.head()
total_long = total.melt(id_vars=['Unnamed: 0'])
sns.lineplot(data=total_long, x='Unnamed: 0', y='value', hue='variable')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
total = run_8.filter(regex='total_|Unnamed').drop(columns='total_genco_wealth')
total.head()
total_long = total.melt(id_vars=['Unnamed: 0'])
sns.lineplot(data=total_long, x='Unnamed: 0', y='value', hue='variable')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
total = run_8.filter(regex='contributed_|Unnamed')
total.head()
total_long = total.melt(id_vars=['Unnamed: 0'])
sns.lineplot(data=total_long, x='Unnamed: 0', y='value', hue='variable')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
