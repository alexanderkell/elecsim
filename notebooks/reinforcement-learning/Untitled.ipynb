# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
run = pd.read_csv('~/Documents/PhD/Projects/10. ELECSIM/run/reinforcement_learning/test_new/demand_none-carbon_none-datetime_2019-07-20_08-32-53-capacity_52152.csv')
run
# Out:
#      Unnamed: 0  contributed_CCGT  contributed_Coal  contributed_Onshore  \
# 0             0              0.00               0.0         13305.748204
# 1             1              0.00               0.0         13057.197170
# 2             2              0.00               0.0         10901.081849
# 3             3              0.00               0.0         13985.752756
# 4             4              0.00               0.0         11182.124013
# 5             5              0.00               0.0         13664.402571
# 6             6              0.00               0.0         12046.205047
# 7             7              0.00               0.0         15587.697774
# 8             8              0.00               0.0         13589.979467
# 9             9              0.00               0.0         13170.388904
# 10           10              0.00               0.0         10965.601379
# 11           11              0.00               0.0         13962.384146
# ...

# %%
total = run.filter(regex='total_|Unnamed').drop(columns='total_genco_wealth')
total.head()
total_long = total.melt(id_vars=['Unnamed: 0'])
sns.lineplot(data=total_long, x='Unnamed: 0', y='value', hue='variable')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
