# %%
import pandas as pd
from scipy.optimize import minimize, root

# %%
data = pd.read_csv('/Users/b1017579/Documents/PhD/Projects/10. ELECSIM/elecsim/data/processed/multi_day_data/4_medoids.csv')
data
# Out:
#      Unnamed: 0  index        date  cluster  hour data_type  capacity_factor
# 0             0      0  2008-11-04     53.0     0      load         0.343182
# 1             1      1  2008-11-04     53.0     1      load         0.336312
# 2             2      2  2008-11-04     53.0     2      load         0.308192
# 3             3      3  2008-11-04     53.0     3      load         0.286708
# 4             4      4  2008-11-04     53.0     4      load         0.247604
# 5             5      5  2008-11-04     53.0     5      load         0.245180
# 6             6      6  2008-11-04     53.0     6      load         0.327890
# 7             7      7  2008-11-04     53.0     7      load         0.514822
# 8             8      8  2008-11-04     53.0     8      load         0.620997
# 9             9      9  2008-11-04     53.0     9      load         0.651374
# 10           10     10  2008-11-04     53.0    10      load         0.672762
# ...

# %%
load_dat = data[data.data_type=="load"]
load_dat
# Out:
#      Unnamed: 0  index        date  cluster  hour data_type  capacity_factor
# 0             0      0  2008-11-04     53.0     0      load         0.343182
# 1             1      1  2008-11-04     53.0     1      load         0.336312
# 2             2      2  2008-11-04     53.0     2      load         0.308192
# 3             3      3  2008-11-04     53.0     3      load         0.286708
# 4             4      4  2008-11-04     53.0     4      load         0.247604
# 5             5      5  2008-11-04     53.0     5      load         0.245180
# 6             6      6  2008-11-04     53.0     6      load         0.327890
# 7             7      7  2008-11-04     53.0     7      load         0.514822
# 8             8      8  2008-11-04     53.0     8      load         0.620997
# 9             9      9  2008-11-04     53.0     9      load         0.651374
# 10           10     10  2008-11-04     53.0    10      load         0.672762
# ...

# %%
data = pd.read_csv('/Users/b1017579/Documents/PhD/Projects/10. ELECSIM/elecsim/data/processed/multi_day_data/4_medoids_scaled.csv')
load_dat = data[data.data_type=='load']
load_total = load_dat.capacity_factor * 98334.86796419
load_total.sum()- 32432.71457*11630
# Out:
# 1.1801719665527344e-05
