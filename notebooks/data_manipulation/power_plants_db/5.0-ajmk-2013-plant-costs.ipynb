# %%
import pandas as pd
pd.set_option('display.max_rows', 1000)

# %%
dat = pd.read_csv('~/Documents/PhD/Projects/10. ELECSIM/elecsim/data/raw/power_plants_costs/historical_costs/2013/2013-plant-costs.csv')
dat.head()
# Out:
#         Unnamed: 0       Gas - CCGT Unnamed: 2 Unnamed: 3
# 0              NaN    Commissioning        NaN        NaN
# 1              NaN   2016 2017 2020        NaN        NaN
# 2  Pre-development    High 20 20 20        NaN        NaN
# 3             £/kW  Medium 10 10 10        NaN        NaN
# 4              NaN        Low 5 5 5        NaN        NaN

# %%
dat_one_col = pd.DataFrame(dat.apply(lambda row: row.dropna().tolist()[0], axis=1))
dat_one_col
# Out:
#                                               0
# 0                                 Commissioning
# 1                                2016 2017 2020
# 2                               Pre-development
# 3                                          £/kW
# 4                                     Low 5 5 5
# 5                            Construction costs
# 6                                          £/kW
# 7                               Low 500 500 500
# 8                                     Fixed O+M
# 9                                       £/MW/yr
# 10                                 Variable O+M
# 11                                        £/MWh
# 12                                    Insurance
# 13                                      £/MW/yr
# 14                           Connection and Use
# 15                            of System charges
# 16                                      £/MW/yr
# 17                                         OCGT
# 18                                Commissioning
# ...

# %%
dat_multi_cols = dat_one_col[0].str.split(' ', expand=True)
dat_multi_cols
# Out:
#                    0             1         2       3             4  \
# 0      Commissioning          None      None    None          None
# 1               2016          2017      2020    None          None
# 2    Pre-development          None      None    None          None
# 3               £/kW          None      None    None          None
# 4                Low             5         5       5          None
# 5       Construction         costs      None    None          None
# 6               £/kW          None      None    None          None
# 7                Low           500       500     500          None
# 8              Fixed           O+M      None    None          None
# 9            £/MW/yr          None      None    None          None
# 10          Variable           O+M      None    None          None
# 11             £/MWh          None      None    None          None
# 12         Insurance          None      None    None          None
# ...

# %%
def manipulate_data(dat):
    print(dat.iloc[0,0])

# %%
dat_multi_cols.groupby(dat_multi_cols.index / 18).apply(lambda x: manipulate_data(x))
# Out:
# Commissioning
# Commissioning
# 2016
# Pre-development
# £/kW
# Low
# Construction
# £/kW
# Low
# Fixed
# £/MW/yr
# Variable
# £/MWh
# Insurance
# £/MW/yr
# Connection
# of
# £/MW/yr
# OCGT
# Commissioning
# 2016
# Pre-development
# £/kW
# Low
# Construction
# £/kW
# Low
# Fixed
# £/MW/yr
# Variable
# £/MWh
# Insurance
# £/MW/yr
# Connection
# of
# £/MW/yr
# Gas
# Commissioning
# FOAK
# Pre-development
# £/kW
# Low
# Construction
# £/kW
# Low
# Fixed
# £/MW/yr
# Variable
# £/MWh
# Insurance
# £/MW/yr
# Connection
# of
# £/MW/yr
# Coal
# Commissioning
# FOAK
# Pre-development
# £/kW
# Low
# Construction
# £/kW
# Low
# Fixed
# £/MW/yr
# Variable
# £/MWh
# Insurance
# £/MW/yr
# Connection
# of
# £/MW/yr
# Coal
# Commissioning
# 2025
# Pre-development
# £/kW
# Low
# Construction
# £/kW
# Low
# Fixed
# £/MW/yr
# Variable
# £/MWh
# Insurance
# £/MW/yr
# Connection
# of
# £/MW/yr
# Nuclear
# Commissioning
# 2020
# Pre-development
# £/kW
# Low
# Construction
# £/kW
# Low
# Fixed
# £/MW/yr
# ...
