# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob
import seaborn as sns

# %%
globbed_files = glob.glob("/Users/b1017579/Documents/PhD/Projects/10. ELECSIM/run/batchrunners/scenarios/data/fourth_run_8_iterations_lower_taxes_no_max_investment_2018/demand_099-carbon_18*")

data=[]
for csv in globbed_files:
    frame = pd.read_csv(csv)
    data.append(frame)
increasing_carbon = pd.concat(data)

increasing_carbon
    
# plot = sns.lineplot(x="Unnamed: 0", y="value", hue='Variables', data=increasing_carbon)
# plt.xlabel('Year')
# plt.ylabel('Share of Energy Mix (%)')
# ax2 = plt.twinx()
# sns.lineplot(x="Unnamed: 0", y="Carbon_tax", data=group, color="black", ax=ax2, linewidth=3, label="Carbon Price")
# ax2.set_ylim(-10,200)
# ax2.set_ylabel("Carbon Tax (£/tonne)")
# Out:
#     Unnamed: 0      CCGT     Coal   Onshore  Offshore      PV  Nuclear  \
# 0            0   31912.0  14475.0    8766.3    6983.8  3377.8   9361.0
# 1            1   69112.0  14475.0   10976.1    6983.8  3409.8   9361.0
# 2            2   69112.0  14475.0   10949.9    6983.8  3425.8   9361.0
# 3            3   69112.0  14475.0   10930.9    6983.8  3489.8   9361.0
# 4            4   69112.0  14475.0   10913.0    6983.8  3585.8   9361.0
# 5            5   69112.0  14475.0   10886.7    6983.8  3633.8   9361.0
# 6            6   69112.0  14475.0   10822.2    6983.8  3681.8   9361.0
# 7            7  110028.0  14475.0   21210.0    6983.8  3729.8   9361.0
# 8            8  104679.0  10507.0   27276.2    6983.8  3793.8   9361.0
# 9            9  118421.0   8486.0   33829.1    6983.8  3841.8   9361.0
# 10          10  142573.0   8486.0   41082.7    6983.8  3857.8   9361.0
# 11          11  179115.0   6162.0   49200.7    6983.8  3873.8   9361.0
# ...
