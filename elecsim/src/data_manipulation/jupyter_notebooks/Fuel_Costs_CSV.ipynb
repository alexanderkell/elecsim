# %%
import pandas as pd

# %%
hist_fuel_costs = pd.read_csv('/Users/b1017579/Documents/PhD/Projects/10. ELECSIM/elecsim/data/fuel_data/fuel_costs/fuel_cost_data/historical_fuel_costs.csv')

# %%
hist_fuel_costs = hist_fuel_costs.drop(['Unnamed: 0','Source'], axis=1)
hist_fuel_costs
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-c46dd6e10256> in <module>()
# ----> 1 hist_fuel_costs = hist_fuel_costs.drop(['Unnamed: 0','Source'], axis=1)
#       2 hist_fuel_costs
#
# /Users/b1017579/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /Users/b1017579/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
# Convert to £/MWh
hist_fuel_costs.loc[:,'1990':'2017'] = hist_fuel_costs.loc[:,'1990':'2017']/100
hist_fuel_costs
# Out:
#    Fuel      Units      1990      1991      1992     1993     1994     1995  \
# 0  Coal  pence/kWh  0.006353  0.006259  0.006600  0.00611  0.00528  0.00500
# 1   Oil  pence/kWh  0.004457  0.004718  0.004813  0.00472  0.00526  0.00684
# 2   Gas  pence/kWh  0.005620  0.006070  0.005950  0.00556  0.00588  0.00584
#
#       1996     1997    ...         2008      2009      2010      2011  \
# 0  0.00507  0.00474    ...     0.009009  0.007534  0.008693  0.011096
# 1  0.00709  0.00746    ...     0.023725  0.022204  0.034873  0.044177
# 2  0.00592  0.00593    ...     0.014810  0.011350  0.013070  0.017110
#
#        2012      2013      2014      2015      2016      2017
# 0  0.009114  0.008424  0.007791  0.006693  0.007465  0.010159
# 1  0.047985  0.044887  0.040530  0.027026  0.023931  0.030828
# 2  0.021355  0.022993  0.018897  0.015855  0.012759  0.015241
#
# [3 rows x 30 columns]

# %%
hist_fuel_costs.loc[:,'Units'] = 'GBP/kWh'
hist_fuel_costs
# Out:
#    Fuel    Units      1990      1991      1992     1993     1994     1995  \
# 0  Coal  GBP/kWh  0.006353  0.006259  0.006600  0.00611  0.00528  0.00500
# 1   Oil  GBP/kWh  0.004457  0.004718  0.004813  0.00472  0.00526  0.00684
# 2   Gas  GBP/kWh  0.005620  0.006070  0.005950  0.00556  0.00588  0.00584
#
#       1996     1997    ...         2008      2009      2010      2011  \
# 0  0.00507  0.00474    ...     0.009009  0.007534  0.008693  0.011096
# 1  0.00709  0.00746    ...     0.023725  0.022204  0.034873  0.044177
# 2  0.00592  0.00593    ...     0.014810  0.011350  0.013070  0.017110
#
#        2012      2013      2014      2015      2016      2017
# 0  0.009114  0.008424  0.007791  0.006693  0.007465  0.010159
# 1  0.047985  0.044887  0.040530  0.027026  0.023931  0.030828
# 2  0.021355  0.022993  0.018897  0.015855  0.012759  0.015241
#
# [3 rows x 30 columns]

# %%
hist_fuel_costs.to_csv('/Users/b1017579/Documents/PhD/Projects/10. ELECSIM/elecsim/data/fuel_data/Fuel costs/historical_fuel_costs/historical_fuel_costs_converted.csv')
