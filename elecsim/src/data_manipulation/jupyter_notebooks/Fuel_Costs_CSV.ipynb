# %%
import pandas as pd

# %%
hist_fuel_costs = pd.read_csv('/Users/b1017579/Documents/PhD/Projects/10. ELECSIM/elecsim/data/fuel_data/fuel_costs/historical_fuel_cost_data/historical_fuel_costs.csv')

# %%
hist_fuel_costs = hist_fuel_costs.drop(['Unnamed: 0','Source','Units'], axis=1)
hist_fuel_costs
# Out:
#                Fuel      1990      1991      1992     1993     1994     1995  \
# 0              Coal  0.006353  0.006259  0.006600  0.00611  0.00528  0.00500
# 1               Oil  0.004457  0.004718  0.004813  0.00472  0.00526  0.00684
# 2               Gas  0.005620  0.006070  0.005950  0.00556  0.00588  0.00584
# 3           Uranium       NaN       NaN       NaN      NaN      NaN      NaN
# 4            Diesel       NaN       NaN       NaN      NaN      NaN      NaN
# 5          Woodchip       NaN       NaN       NaN      NaN      NaN      NaN
# 6    Poultry_litter       NaN       NaN       NaN      NaN      NaN      NaN
# 7             Straw       NaN       NaN       NaN      NaN      NaN      NaN
# 8              Meat       NaN       NaN       NaN      NaN      NaN      NaN
# 9   Waste_post_2000       NaN       NaN       NaN      NaN      NaN      NaN
# 10   Waste_pre_2000       NaN       NaN       NaN      NaN      NaN      NaN
#
# ...

# %%
hist_fuel_costs_long = pd.melt(hist_fuel_costs, id_vars=['Fuel'], var_name='Price', value_vars=list(hist_fuel_costs.loc[:,'1990':'2018'].columns))
hist_fuel_costs_long
# Out:
#                 Fuel Price     value
# 0               Coal  1990  0.006353
# 1                Oil  1990  0.004457
# 2                Gas  1990  0.005620
# 3            Uranium  1990       NaN
# 4             Diesel  1990       NaN
# 5           Woodchip  1990       NaN
# 6     Poultry_litter  1990       NaN
# 7              Straw  1990       NaN
# 8               Meat  1990       NaN
# 9    Waste_post_2000  1990       NaN
# 10    Waste_pre_2000  1990       NaN
# 11              Coal  1991  0.006259
# 12               Oil  1991  0.004718
# 13               Gas  1991  0.006070
# 14           Uranium  1991       NaN
# 15            Diesel  1991       NaN
# 16          Woodchip  1991       NaN
# 17    Poultry_litter  1991       NaN
# 18             Straw  1991       NaN
# 19              Meat  1991       NaN
# 20   Waste_post_2000  1991       NaN
# 21    Waste_pre_2000  1991       NaN
# 22              Coal  1992  0.006600
# 23               Oil  1992  0.004813
# ...

# %%
hist_fuel_costs_long.to_csv('/Users/b1017579/Documents/PhD/Projects/10. ELECSIM/elecsim/data/fuel_data/fuel_costs/historical_fuel_cost_data/historical_fuel_costs_converted_long.csv')
